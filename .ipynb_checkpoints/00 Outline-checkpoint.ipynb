# %% [markdown]
# # 简单粗暴的tensorflow2.0笔记
# 学习网站：https://www.bilibili.com/video/BV1K7411J75M?p=3<br/>
# 笔记整理：https://blog.csdn.net/qq_41709378 <br/>
# 文档网址：https://tf.wiki/zh_hans/basic/basic.html#tensorflow-1-1
#
# 运行环境：tf2.0 + python 3.7 <br>
#
#
# ## **学习课程路线：**
# ### [1] 第一部分：TensorFlow 基础 <br/>
#    &emsp; 1.1 TensorFlow 模块  <br/>
#    &emsp; 1.2 自动求导机制  <br/>
#    &emsp; 1.3 基础示例：线性回归  <br/>
#
#
# ### [2] 第二部分：TensorFlow 模型建立与训练 <br/>
#    &emsp; 2.1 模型（Model）与层（Layer） <br/>
#    &emsp; 2.2 基础示例：多层感知机（MLP） <br/>
#    &emsp; 2.3 卷积神经网络（CNN） <br/>
#    &emsp; 2.4 循环神经网络（RNN） <br/>
#    &emsp; 2.4 深度强化学习（DRL） <br/>
#    &emsp; 2.5 Keras Pipeline * <br/>
#    &emsp; 2.6 自定义层、损失函数和评估指标 *  <br/>
#
#
# ### [3] 第三部分：TensorFlow 常用模块  <br/>
#    &emsp; 3.1 tf.train.Checkpoint ：变量的保存与恢复 <br/>
#    &emsp; 3.2 TensorBoard：训练过程可视化 <br/>
#    &emsp; 3.3 tf.data ：数据集的构建与预处理 <br/>
#    &emsp; 3.4 TFRecord ：TensorFlow 数据集存储格式 <br/>
#    &emsp; 3.5 tf.function ：图执行模式 * <br/>
#    &emsp; 3.6 tf.TensorArray ：TensorFlow 动态数组 * <br/>
#    &emsp; 3.7 tf.config：GPU 的使用与分配 *  <br/>
#
#
# ### [4] 第四部分：TensorFlow 模型导出  <br/>
#    &emsp; 4.1 使用 SavedModel 完整导出模型 <br/>
#    &emsp; 4.2 Keras 自有的模型导出格式（Jinpeng） <br/>
#
#
# ### [5] 第五部分：TensorFlow Serving  <br/>
#    &emsp; 5.1 TensorFlow Serving 安装 <br/>
#    &emsp; 5.2 TensorFlow Serving 模型部署 <br/>
#    &emsp; 5.3 在客户端调用以 TensorFlow Serving 部署的模型 <br/>
#
#
# ### [6] 第六部分：TensorFlow Lite（Jinpeng)  <br/>
#    &emsp; 6.1 模型转换 <br/>
#    &emsp; 6.2 Android 部署 <br/>
#    &emsp; 6.3 Quantization 模型转换 <br/>
#    &emsp; 6.4 总结 <br/>
#
#
# ### [7] 第七部分：TensorFlow in JavaScript（Huan） <br/>
#    &emsp; 7.1 TensorFlow Serving 安装 <br/>
#    &emsp; 7.2 TensorFlow Serving 模型部署 <br/>
#    &emsp; 7.3 在客户端调用以 TensorFlow Serving 部署的模型 <br/>
#
#
# ### [8] 第八部分：大规模训练与加速 <br/>
#    &emsp; 8.1 TensorFlow 分布式训练 <br/>
#    &emsp; 8.1 单机多卡训练： MirroredStrategy <br/>
#    &emsp; 8.2 多机训练： MultiWorkerMirroredStrategy <br/>
#    &emsp; 8.3 使用 TPU 训练 TensorFlow 模型（Huan） <br/>
